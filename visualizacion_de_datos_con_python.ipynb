# %% [markdown]
# <a href="https://colab.research.google.com/github/vanessa-oreza/python/blob/main/visualizacion_de_datos_con_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualización de datos con Python: Matplotlib, Seaborn y Plotly

# %%
import pandas as pd
df=pd.read_csv('/content/inmigrantes_canada.csv')

# %%
df
# Out:
#                   Pais Continente            Region  1980  1981  1982  1983  \
# 0           Afganistán       Asia       Sur de Asia    16    39    39    47
# 1              Albania     Europa     Sur de Europa     1     0     0     0
# 2              Argelia     África   Norte de África    80    67    71    69
# 3      Samoa Americana    Oceanía         Polinesia     0     1     0     0
# 4              Andorra     Europa     Sur de Europa     0     0     0     0
# ..                 ...        ...               ...   ...   ...   ...   ...
# 190            Vietnam       Asia  Sudeste Asiático  1191  1829  2162  3404
# 191  Sahara Occidental     África   Norte de África     0     0     0     0
# 192              Yemen       Asia   Asia Occidental     1     2     1     6
# 193             Zambia     África   África Oriental    11    17    11     7
# 194           Zimbabue     África   África Oriental    72   114   102    44
#
# ...

# %%
df.set_index('Pais',inplace=True)

# %%
df
# Out:
#                   Continente            Region  1980  1981  1982  1983  1984  \
# Pais
# Afganistán              Asia       Sur de Asia    16    39    39    47    71
# Albania               Europa     Sur de Europa     1     0     0     0     0
# Argelia               África   Norte de África    80    67    71    69    63
# Samoa Americana      Oceanía         Polinesia     0     1     0     0     0
# Andorra               Europa     Sur de Europa     0     0     0     0     0
# ...                      ...               ...   ...   ...   ...   ...   ...
# Vietnam                 Asia  Sudeste Asiático  1191  1829  2162  3404  7583
# Sahara Occidental     África   Norte de África     0     0     0     0     0
# Yemen                   Asia   Asia Occidental     1     2     1     6     0
# Zambia                África   África Oriental    11    17    11     7    16
# Zimbabue              África   África Oriental    72   114   102    44    32
#
# ...

# %%
years=list(map(str,range(1980,2014)))
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
colombia=df.loc['Colombia',years]
colombia
# Out:
# 1980     266
# 1981     326
# 1982     360
# 1983     244
# 1984     235
# 1985     214
# 1986     257
# 1987     376
# 1988     352
# 1989     439
# 1990     614
# 1991     652
# 1992     582
# 1993     464
# 1994     375
# 1995     371
# 1996     381
# 1997     578
# 1998     929
# 1999    1306
# 2000    2259
# 2001    2965
# 2002    3283
# 2003    4318
# 2004    4566
# 2005    6424
# 2006    6535
# 2007    5357
# 2008    5452
# 2009    4652
# 2010    5218
# 2011    4366
# 2012    3741
# 2013    3631
# Name: Colombia, dtype: object

# %%
col_dict={'Año' : colombia.index.tolist(),
          'Inmigrantes': colombia.values.tolist()}

# %%
datos_col=pd.DataFrame(col_dict)
datos_col.tail()
# Out:
#      Año  Inmigrantes
# 29  2009         4652
# 30  2010         5218
# 31  2011         4366
# 32  2012         3741
# 33  2013         3631

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,4))
plt.plot(datos_col['Año'],datos_col['Inmigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.title('Inmigración de colombianos a Canadá')
plt.xlabel('Año')
plt.ylabel('Cantidad de inmigrantes')
plt.show()

# %% [markdown]
# ##Desafío

# %% [markdown]
# Crear un gráfico de líneas comparando los números de inmigrantes de Brasil y Argentina a Canadá, los dos países más grandes de Sudamérica.

# %%
brasil=df.loc['Brasil',years]
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
arg=df.loc['Argentina',years]
arg
# Out:
# 1980     368
# 1981     426
# 1982     626
# 1983     241
# 1984     237
# 1985     196
# 1986     213
# 1987     519
# 1988     374
# 1989     538
# 1990     678
# 1991     763
# 1992    1023
# 1993    1022
# 1994     366
# 1995     380
# 1996     396
# 1997     391
# 1998     349
# 1999     318
# 2000     427
# 2001     635
# 2002     865
# 2003    1745
# 2004    1591
# 2005    1153
# 2006     847
# 2007     620
# 2008     540
# 2009     467
# 2010     459
# 2011     278
# 2012     263
# 2013     282
# Name: Argentina, dtype: object

# %%
br_dict={'Año' : brasil.index.tolist(),
          'Inmigrantes': brasil.values.tolist()}

# %%
arg_dict={'Año' : arg.index.tolist(),
          'Inmigrantes': arg.values.tolist()}

# %%
datos_br=pd.DataFrame(br_dict)
datos_br.tail()
# Out:
#      Año  Inmigrantes
# 29  2009         2509
# 30  2010         2598
# 31  2011         1508
# 32  2012         1642
# 33  2013         1714

# %%
datos_arg=pd.DataFrame(arg_dict)
datos_arg.tail()
# Out:
#      Año  Inmigrantes
# 29  2009          467
# 30  2010          459
# 31  2011          278
# 32  2012          263
# 33  2013          282

# %%
plt.figure(figsize=(8,4))
plt.plot(datos_col['Año'],datos_br['Inmigrantes'])
plt.plot(datos_col['Año'],datos_arg['Inmigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.title('Inmigración de brasileños y argentinos a Canadá')
plt.xlabel('Año')
plt.ylabel('Cantidad de inmigrantes')
plt.legend()
plt.show()
# Out:
# <ipython-input-17-fa92d7ef35f0>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Referencia: https://www.youtube.com/watch?v=AYorFcI1MTU

# %% [markdown]
# Análisis
# ¿Hay alguna tendencia o patrón común en los datos de ambos países?
#
# Considero que sí, ambos países tienen ascendencia y descendencia al final.
#
# ¿Cuáles son los períodos con mayor número de inmigrantes en ambos países?
#
# Argentina: 2003 con 1745 inmigrantes
#
# Brasil: 2010 con 2598
#
# ¿Estás listo para avanzar? Sí!

# %% [markdown]
# ##Opinión del instructor

# %%
df_comparacion = df.loc[['Brasil', 'Argentina'], years]

# %%
df_comparacion = df_comparacion.T

# %%
df_comparacion.head()
# Out:
# Pais  Brasil  Argentina
# 1980     211        368
# 1981     220        426
# 1982     192        626
# 1983     139        241
# 1984     145        237

# %%
plt.plot(df_comparacion['Brasil'], label='Brasil')
plt.plot(df_comparacion['Argentina'], label='Argentina')
plt.title('Inmigración de Brasil y Argentina a Canadá')
plt.xlabel('Año')
plt.ylabel('Número de Inmigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %% [markdown]
# Análisis
#
# Con este gráfico, podemos observar que las tendencias de inmigración en Brasil y Argentina eran bastante similares al principio del período. Sin embargo, a partir de los años 2000, los números de inmigrantes en Argentina comenzaron a aumentar y alcanzaron los valores más altos entre 2000 y 2005, antes de disminuir y alcanzar valores muy bajos en los años más recientes. Por otro lado, en el caso de Brasil, los aumentos en la inmigración comenzaron después de 2005 y parecen haber alcanzado el valor más alto en 2010.

# %% [markdown]
# #Creando figuras con Matplotlib

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(datos_col['Año'],datos_col['Inmigrantes'])
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Inmigración de colombianos hacia Canadá\n1980-2013')
ax.set_xlabel('Año')
ax.set_ylabel('Número de inmigrantes')
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(10,4))
axs[0].plot(datos_col['Año'],datos_col['Inmigrantes'])
axs[0].set_title('Inmigración de colombianos a Canadá\n 1980-2013')
axs[0].set_xlabel('Año')
axs[0].set_ylabel('Cantidad de inmigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))

axs[1].boxplot(datos_col['Inmigrantes'])
axs[1].set_title('Boxplot de la inmigración de colombianos hacia Canadá\n 1980-2013')
axs[0].set_xlabel('Año')
axs[0].set_ylabel('Cantidad de inmigrantes')

plt.show()

# %%
datos_col.describe()
# Out:
#        Inmigrantes
# count    34.000000
# mean   2120.235294
# std    2163.761316
# min     214.000000
# 25%     372.000000
# 50%     633.000000
# 75%    4173.750000
# max    6535.000000

# %%
fig, axs = plt.subplots(2,2,figsize=(10,6))
fig.subplots_adjust(hspace=0.5,wspace=0.3)
fig.suptitle('Inmigración de los 4 países más grandes de Sudamérica\n 1980-2013')

axs[0,0].plot(df.loc['Colombia',years])
axs[0,0].set_title('Colombia')

axs[0,1].plot(df.loc['Brasil',years])
axs[0,1].set_title('Brasil')

axs[1,0].plot(df.loc['Argentina',years])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Perú',years])
axs[1,1].set_title('Perú')

ymin=0
ymax=7000

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)

for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  ax.set_xlabel('Año')
  ax.set_ylabel('Número de inmigrantes')
  ax.grid()


plt.show()

# %% [markdown]
# ##Desafío
# Visualizando datos de ventas de tiendas diferentes

# %%
tiendas = ['A', 'B', 'C', 'D']
ventas_2022 = {'Ene': [100, 80, 150, 50],
    'Feb': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'May': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Sep': [240, 160, 290, 130],
    'Oct': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dec': [300, 350, 400, 250]}

# %%
#Para crear un DataFrame con estos datos, utilizando la columna "tiendas" como índice, puedes ejecutar el siguiente código:
df1 = pd.DataFrame(ventas_2022, index=tiendas)
df1
# Out:
#    Ene  Feb  Mar  Abr  May  Jun  Jul  Ago  Sep  Oct  Nov  Dec
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
#Para crear los cuatro gráficos
fig, axs=plt.subplots(2,2,figsize=(14,8))

#Ajustar los espaciados entre los subgráficos
plt.subplots_adjust(hspace=0.5, wspace=0.3)

#Título superior
fig.suptitle('Ventas de cuatro tiendas en el 2022')

#Cuatro gráficos
axs[0,0].plot(df1.loc['A'])
axs[0,0].set_title('Ventas en la tienda A')

axs[0,1].plot(df1.loc['B'])
axs[0,1].set_title('Ventas en la tienda B')

axs[1,0].plot(df1.loc['C'])
axs[1,0].set_title('Ventas en la tienda C')

axs[1,1].plot(df1.loc['D'])
axs[1,1].set_title('Ventas en la tienda D')

# Agregar etiquetas para los ejes X y Y

for ax in axs.flat:
    ax.set_xlabel('Mes')
    ax.set_ylabel('Número de ventas')

#Definir el mismo límite en Y
ymin=0
ymax=400

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)



#No mostrar el espacio de memoria
plt.show()

# %% [markdown]
# #Personalizando visualizaciones con matplotlib

# %%
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(datos_col['Año'],datos_col['Inmigrantes'],lw=1.5,color='g')  #marker='o'
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Inmigración de colombianos hacia Canadá\n1980-2013', fontsize=18, loc='left')
ax.set_xlabel('Año', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.grid(linestyle='--')
ax.set_ylabel('Número de inmigrantes',fontsize=14)
plt.show()

# %%
sudamerica=df.query('Region == "América del Sur"')
sudamerica.head(10)
# Out:
#                            Continente           Region  1980  1981  1982  \
# Pais
# Argentina  América Latina y el Caribe  América del Sur   368   426   626
# Bolivia    América Latina y el Caribe  América del Sur    44    52    42
# Brasil     América Latina y el Caribe  América del Sur   211   220   192
# Chile      América Latina y el Caribe  América del Sur  1233  1069  1078
# Colombia   América Latina y el Caribe  América del Sur   266   326   360
# Ecuador    América Latina y el Caribe  América del Sur   238   207   184
# Guyana     América Latina y el Caribe  América del Sur  2334  2943  3575
# Paraguay   América Latina y el Caribe  América del Sur    45    26    32
# Perú       América Latina y el Caribe  América del Sur   317   456   401
# Surinam    América Latina y el Caribe  América del Sur    15    10    21
#
#            1983  1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  \
# Pais                                     ...
# ...

# %%
colores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'grey', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12,5))
ax.bar(sudamerica.index,sudamerica['Total'],color=colores)
ax.set_title('Inmigración de sudamericanos hacia Canadá\n de 1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('')
ax.set_ylabel('Número de inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=10)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %%
colores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'grey', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12,5))
ax.barh(sudamerica.index,sudamerica['Total'],color=colores)
ax.set_title('Inmigración de sudamericanos hacia Canadá\n de 1980 a 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Número de inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=10)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %%
sudamerica_sorted=sudamerica.sort_values('Total',ascending=True)
colores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'grey', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12,5))
ax.barh(sudamerica_sorted.index,sudamerica_sorted['Total'],color=colores)
ax.set_title('Inmigración de sudamericanos hacia Canadá\n de 1980 a 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Número de inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=10)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %%
colores=[]
for pais in sudamerica_sorted.index:
  if pais == 'Colombia':
    colores.append('forestgreen')
  else:
   colores.append('silver')

sudamerica_sorted=sudamerica.sort_values('Total',ascending=True)

fig, ax = plt.subplots(figsize=(12,5))

ax.set_frame_on(False)
ax.xaxis.set_visible(False)
ax.tick_params(axis='y',which='both',size=0)

ax.barh(sudamerica_sorted.index,sudamerica_sorted['Total'],color=colores)
ax.set_title('Sudamérica: Colombia es el segundo país con más migrantes\nhacia Canadá durante el periodo 1980-2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.yaxis.set_tick_params(labelsize=12)

#ax.set_xlabel('Número de inmigrantes', fontsize=13)
#ax.xaxis.set_tick_params(labelsize=10)

for i,j in enumerate(sudamerica_sorted['Total']):
  ax.text(j+20,i,str(j),color='black',fontsize=8.5,ha='left',va='center')

fig.savefig('/content/inmigrantes_sudamericanos.png',
            transparent=False, dpi=300, bbox_inches='tight')

plt.show()

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(datos_col['Año'],datos_col['Inmigrantes'],lw=2,color='g')  #marker='o'
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Inmigración de colombianos hacia Canadá\n1980-2013', fontsize=18, loc='left')
ax.set_xlabel('Año', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.set_ylabel('Número de inmigrantes',fontsize=14)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig('/content/inmigrantes_colombianos_fondo-transparente.png',
            transparent=True, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##Desafío
# Personaliza las gráficas de las ventas de las cuatro tiendas diferentes de 2022

# %%
#Para crear los cuatro gráficos
fig, axs=plt.subplots(2,2,figsize=(14,8))

#Ajustar los espaciados entre los subgráficos
plt.subplots_adjust(hspace=0.5, wspace=0.3)

#Título superior
fig.suptitle('Ventas de cuatro tiendas en el 2022', fontsize=18)

#Cuatro gráficos
axs[0,0].plot(df1.loc['A'],lw=2, color="blue")
axs[0,0].set_title('Ventas en la tienda A', loc='left')


axs[0,1].plot(df1.loc['B'],lw=2, color="red")
axs[0,1].set_title('Ventas en la tienda B', loc='left')

axs[1,0].plot(df1.loc['C'],lw=2, color="purple")
axs[1,0].set_title('Ventas en la tienda C', loc='left')

axs[1,1].plot(df1.loc['D'],lw=2, color="g")
axs[1,1].set_title('Ventas en la tienda D', loc='left')

# Agregar etiquetas para los ejes X y Y

for ax in axs.flat:
    ax.set_xlabel('Mes', fontsize=13)
    ax.set_ylabel('Número de ventas', fontsize=13)
    ax.xaxis.set_tick_params(labelsize=11)
    ax.yaxis.set_tick_params(labelsize=10)
    #Quitar márgenes
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

#Definir el mismo límite en Y
ymin=0
ymax=400

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)


#No mostrar el espacio de memoria
plt.show()

# %% [markdown]
# #Conociendo la biblioteca Seaborn

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
top_10 = df.sort_values('Total', ascending=False).head(10)
top_10
# Out:
#                        Continente             Region   1980   1981   1982  \
# Pais
# India                        Asia        Sur de Asia   8880   8670   8147
# China                        Asia      Asia Oriental   5123   6682   3308
# Reino Unido                Europa    Norte de Europa  22045  24796  20620
# Filipinas                    Asia   Sudeste Asiático   6051   5921   5249
# Pakistán                     Asia        Sur de Asia    978    972   1201
# Estados Unidos  América del Norte  América del Norte   9378  10030   9074
# Irán                         Asia        Sur de Asia   1172   1429   1822
# Sri Lanka                    Asia        Sur de Asia    185    371    290
# Corea del Sur                Asia      Asia Oriental   1011   1456   1572
# Polonia                    Europa    Europa Oriental    863   2930   5881
#
#                  1983   1984  1985  1986   1987  ...   2005   2006   2007  \
# Pais                                             ...
# ...

# %%
sns.barplot(data=top_10,x='Total',y=top_10.index,orient='h')
ax.set(title='Top 10 países con mayor migración hacia Canadá\n1980-2013',
       xlabel='Número de inmigrantes',
       ylabel='Países')
plt.show()

# %%
#No funcionó lo de los labels

# %%
fig, ax=plt.subplots(figsize=(8,4))

ax=sns.barplot(data=top_10,x='Total',y=top_10.index, orient='h')
ax.set_title('Top 10 países con mayor migración hacia Canadá\n1980-2013',
             loc='left', fontsize=16)
ax.set_xlabel('Número de inmigrantes', fontsize=14)
ax.set_ylabel('')
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
def generar_grafico(palette):
  fig, ax=plt.subplots(figsize=(8,4))
  ax.set(xticklabels=[])
  ax=sns.barplot(data=top_10,x='Total',y=top_10.index,hue=top_10.index, orient='h',
                 palette=palette,legend=False)
  ax.set_title('Top 10 países con mayor migración hacia Canadá\n1980-2013',
              loc='left', fontsize=16)
  ax.set_xlabel('Número de inmigrantes', fontsize=14)
  ax.set_ylabel('')
  sns.despine()
  for i,j in enumerate(top_10['Total']):
    ax.text(j+20,i,str(j),color='black',fontsize=9,ha='left',va='center')
  plt.show()

# %%
sns.set_theme(style='darkgrid')
generar_grafico('tab10')

# %%
generar_grafico('rocket')

# %%
generar_grafico('coolwarm')

# %%
generar_grafico('Blues_r')

# %%
sns.set_theme(style='white')
generar_grafico('tab10')

# %% [markdown]
# ##Desafío

# %%
#Para crear los cuatro gráficos
fig, axs=plt.subplots(2,2,figsize=(14,8))

#Ajustar los espaciados entre los subgráficos
plt.subplots_adjust(hspace=0.5, wspace=0.3)

#Título superior
fig.suptitle('Ventas de cuatro tiendas en el 2022', fontsize=18)

#Cuatro gráficos
axs[0,0].plot(df1.loc['A'],lw=2, color="blue")
axs[0,0].set_title('Ventas en la tienda A', loc='left')


axs[0,1].plot(df1.loc['B'],lw=2, color="red")
axs[0,1].set_title('Ventas en la tienda B', loc='left')

axs[1,0].plot(df1.loc['C'],lw=2, color="purple")
axs[1,0].set_title('Ventas en la tienda C', loc='left')

axs[1,1].plot(df1.loc['D'],lw=2, color="g")
axs[1,1].set_title('Ventas en la tienda D', loc='left')

# Agregar etiquetas para los ejes X y Y

for ax in axs.flat:
    ax.set_xlabel('Mes', fontsize=13)
    ax.set_ylabel('Número de ventas', fontsize=13)
    ax.xaxis.set_tick_params(labelsize=11)
    ax.yaxis.set_tick_params(labelsize=10)
    #Quitar márgenes
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

#Definir el mismo límite en Y
ymin=0
ymax=400

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)


#No mostrar el espacio de memoria
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Aplicar un tema de Seaborn
sns.set_theme(style="whitegrid")  # Puedes probar con "dark", "white", "ticks", etc.

# Crear los gráficos
fig, ax = plt.subplots(figsize=(8, 4))

# Dibujar las líneas con etiquetas para la leyenda
ax.plot(df1.loc['A'], lw=2, color='blue', label='Tienda A')
ax.plot(df1.loc['B'], lw=2, color='red', label='Tienda B')
ax.plot(df1.loc['C'], lw=2, color='purple', label='Tienda C')
ax.plot(df1.loc['D'], lw=2, color='green', label='Tienda D')

# Título y etiquetas
ax.set_title('Ventas en las tiendas A, B, C y D', loc='left')
ax.set_xlabel('Mes', fontsize=13)
ax.set_ylabel('Número de ventas', fontsize=13)
ax.xaxis.set_tick_params(labelsize=11)
ax.yaxis.set_tick_params(labelsize=10)

# Leyenda
ax.legend(title='Tiendas', loc='upper left')

# Quitar bordes
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Limites del eje Y
ax.set_ylim(0, 400)

# Mostrar gráfico
plt.show()

# %%
# prompt: utilizar una biblioteca de seaborn

#Creando un gráfico de líneas con Seaborn
plt.figure(figsize=(8,4))
sns.lineplot(data=datos_col, x='Año', y='Inmigrantes')
plt.title('Inmigración de colombianos a Canadá (Seaborn)')
plt.xlabel('Año')
plt.ylabel('Cantidad de inmigrantes')
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.show()

# Crear un gráfico de líneas comparando los números de inmigrantes de Brasil y Argentina con Seaborn
plt.figure(figsize=(8,4))
sns.lineplot(data=datos_br, x='Año', y='Inmigrantes', label='Brasil')
sns.lineplot(data=datos_arg, x='Año', y='Inmigrantes', label='Argentina')
plt.title('Inmigración de brasileños y argentinos a Canadá (Seaborn)')
plt.xlabel('Año')
plt.ylabel('Cantidad de inmigrantes')
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.legend()
plt.show()

# %%
sns.set_theme()
sns.set_palette('Dark2')

fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(df.loc['Brasil', years], label='Brasil', lw=3)
ax = sns.lineplot(df.loc['Argentina', years], label='Argentina', lw=3)
ax = sns.lineplot(df.loc['Perú', years], label='Perú', lw=3)
ax = sns.lineplot(df.loc['Colombia', years], label='Colombia', lw=3)

ax.set_title('Inmigración de los principales países de América del Sur\nal Canadá de 1980 a 2013', loc='left', fontsize=20)
ax.set_xlabel('Año', fontsize=14)
ax.set_ylabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.18, 1.02))

plt.show()

# %%
#Para crear los cuatro gráficos
fig, ax=plt.subplots(figsize=(8,4))
#Un gráfico
ax=sns.lineplot(df1.loc['A'],lw=2,palette='rocket')
ax=sns.lineplot(df1.loc['B'],lw=2,palette='rocket')
ax=sns.lineplot(df1.loc['C'],lw=2,palette='rocket')
ax=sns.lineplot(df1.loc['D'],lw=2,palette='rocket')
ax.set_title('Ventas en las tiendas A, B, C y D', loc='left')
ax.legend()

# Agregar etiquetas para los ejes X y Y
ax.set_xlabel('Mes', fontsize=13)
ax.set_ylabel('Número de ventas', fontsize=13)
ax.xaxis.set_tick_params(labelsize=11)
ax.yaxis.set_tick_params(labelsize=10)
#Quitar márgenes
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#Definir el mismo límite en Y
ymin=0
ymax=400
ax.set_ylim(ymin, ymax)

#No mostrar el espacio de memoria
plt.show()
# Out:
# <ipython-input-53-fc8e325353a2>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.lineplot(df1.loc['A'],lw=2,palette='rocket')
# <ipython-input-53-fc8e325353a2>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.lineplot(df1.loc['B'],lw=2,palette='rocket')
# <ipython-input-53-fc8e325353a2>:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.lineplot(df1.loc['C'],lw=2,palette='rocket')
# <ipython-input-53-fc8e325353a2>:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.lineplot(df1.loc['D'],lw=2,palette='rocket')
# <ipython-input-53-fc8e325353a2>:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# # Gráficos interactivos con Plotly

# %% [markdown]
# https://plotly.com/python/

# %%
import plotly.express as px

# %%
fig=px.line(datos_col, x='Año',y='Inmigrantes',
            title='Inmigrantes colombianos hacia Canadá entre 1980 y 2013')
fig=px.line(datos_col, x='Año',y='Inmigrantes',
            title='Inmigrantes colombianos hacia Canadá entre 1980 y 2013')
fig.update_layout(width=800,height=400,xaxis={'tickangle':-45},
                  xaxis_title='Año', yaxis_title='Número de inmigrantes',
                  font_family='Arial', font_size=14, font_color='grey')
fig.update_traces(line_color='teal', line_width=2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sudamerica.drop(['Continente', 'Region', 'Total'], axis=1, inplace=True)
# Out:
# <ipython-input-56-53d945d27281>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sudamerica=sudamerica.T
sudamerica
# Out:
# Pais  Argentina  Bolivia  Brasil  Chile  Colombia  Ecuador  Guyana  Paraguay  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
# 1985        196       44     130    533       214      208    2299        36
# 1986        213       79     205    633       257      240    3942        34
# 1987        519      165     244   1454       376      344    6174        72
# 1988        374       63     394    990       352      265    2977        53
# 1989        538       68     650   1023       439      278    3270        48
# 1990        678       71     650   1286       614      552    2824        56
# ...

# %%
fig=px.line(sudamerica, x=sudamerica.index,y=sudamerica.columns,
            title='Inmigrantes de Sudamérica hacia Canadá entre 1980 y 2013',
            color='Pais',markers=True)
fig.update_layout(width=900,height=600,xaxis={'tickangle':-45},
                  xaxis_title='Año', yaxis_title='Número de inmigrantes',
                  font_family='Arial', font_size=14, font_color='grey')
fig.write_html('/content/inmgracion_sudamericanos.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Animacion con Plotly

# %%
datos_col['Año'] = datos_col['Año'].astype(int)

# %%
import plotly.graph_objs as go

# Creando una figura
fig = go.Figure()

# Adicionando una línea en el  gráfico y definiendo el espesor de la linea
fig.add_trace(
    go.Scatter(x=[datos_col['Año'].iloc[0]], y=[datos_col['Inmigrantes'].iloc[0]], mode='lines',
               name='Inmigrantes', line=dict(width=4))
)

# Definir la configuración del layout
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Colombianos hacia Canadá en el periodo de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 7000], autorange=False, title='<b>Número de Inmigrantes</b>'),
    updatemenus=[dict(type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}])]
    )],
    width=1000,
    height=500
)

# Definir la configuración de la animación
frames = [go.Frame(data=[go.Scatter(x=datos_col['Año'].iloc[:i+1], y=datos_col['Inmigrantes'].iloc[:i+1])]) for i in range(len(datos_col))]
fig.frames = frames

# Mostrar la figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Desafío

# %%
datos_arg['Año'] = datos_arg['Año'].astype(int)
datos_br['Año'] = datos_br['Año'].astype(int)

# %%
datos_arg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Año          34 non-null     int64
#  1   Inmigrantes  34 non-null     int64
#  2   País         34 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 948.0+ bytes

# %%
import plotly.graph_objs as go

# Creando una figura
fig = go.Figure()

# Agregando la línea con los datos de Brasil
fig.add_trace(
    go.Scatter(x=[datos_br['Año'].iloc[0]], y=[datos_br['Inmigrantes'].iloc[0]], mode='lines',
               name='Inmigrantes de Brasil', line=dict(width=3)))

# Agregando la línea con los datos de Argentina
fig.add_trace(
    go.Scatter(x=[datos_arg['Año'].iloc[0]], y=[datos_arg['Inmigrantes'].iloc[0]], mode='lines',
               name='Inmigrantes de Argentina', line=dict(width=3)))

# Definiendo las configuraciones de diseño
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Brasil y Argentina a Canadá en el período de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=18)),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de inmigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=950, # Ancho de la figura en píxeles
    height=500 # Altura de la figura en píxeles
)

# Definiendo las configuraciones de animación
frames = []
for i in range(len(datos_arg)):
    frame_data = [go.Scatter(x=datos_br['Año'].iloc[:i+1], y=datos_br['Inmigrantes'].iloc[:i+1]),
        go.Scatter(x=datos_arg['Año'].iloc[:i+1], y=datos_arg['Inmigrantes'].iloc[:i+1])]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

# Mostrando la figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
